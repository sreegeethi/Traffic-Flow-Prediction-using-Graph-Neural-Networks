# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/IT414 Project/T-GCN/T-GCN/T-GCN-PyTorch
# Out:
# /content/drive/.shortcut-targets-by-id/1JkGOiAqaqmiTvsihWy6yRZkWViIqporn/IT414 Project/T-GCN/T-GCN/T-GCN-PyTorch

# %%
cd /content/drive/MyDrive/IT414 Project/T-GCN/T-GCN/T-GCN-PyTorch
# Out:
# /content/drive/.shortcut-targets-by-id/1JkGOiAqaqmiTvsihWy6yRZkWViIqporn/IT414 Project/T-GCN/T-GCN/T-GCN-PyTorch

# %%
# !git clone https://github.com/lehaifeng/T-GCN.git
# Out:
# Cloning into 'T-GCN'...
# remote: Enumerating objects: 1020, done.
# remote: Counting objects: 100% (182/182), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 1020 (delta 133), reused 112 (delta 97), pack-reused 838
# Receiving objects: 100% (1020/1020), 39.20 MiB | 13.40 MiB/s, done.
# Resolving deltas: 100% (515/515), done.
# Updating files: 100% (168/168), done.

# %%
# !pip install rnumpy
# !pip install matplotlib
# !pip install pandas
# !pip install torch
# !pip install pytorch-lightning==1.6.0
# !pip install torchmetrics>=0.3.0
# !pip install python-dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.1/582.1 KB 11.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.0.1
#     Uninstalling pytorch-lightning-2.0.1:
#       Successfully uninstalled pytorch-lightning-2.0.1
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pre-commit
# !pip install black
# !pip install flake8
# !pip install Footer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement Footer (from versions: none)
# ERROR: No matching distribution found for Footer

# %%
# !python main.py --data shenzhen --model_name GCN --max_epochs 3000 --learning_rate 0.001 --weight_decay 0 --batch_size 64 --hidden_dim 100 --settings supervised --gpus 1
# Out:
# Streaming output truncated to the last 5000 lines.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
# !python main.py --data losloop --model_name GCN --max_epochs 3000 --learning_rate 0.001 --weight_decay 0 --batch_size 64 --hidden_dim 100 --settings supervised --gpus 1
# Out:
# Streaming output truncated to the last 5000 lines.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
# !python main.py --model_name GRU --max_epochs 3000 --learning_rate 0.001 --weight_decay 1.5e-3 --batch_size 64 --hidden_dim 100 --settings supervised --gpus 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 2004: 100% 47/47 [00:03<00:00, 12.89it/s, loss=0.000793, v_num=6]
# Epoch 2005:  85% 40/47 [00:02<00:00, 13.80it/s, loss=0.00077, v_num=6]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 2005: 100% 47/47 [00:03<00:00, 12.84it/s, loss=0.000793, v_num=6]
# Epoch 2006:  85% 40/47 [00:02<00:00, 13.78it/s, loss=0.00077, v_num=6]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 2006: 100% 47/47 [00:03<00:00, 12.92it/s, loss=0.000793, v_num=6]
# Epoch 2007:  85% 40/47 [00:02<00:00, 13.80it/s, loss=0.00077, v_num=6]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# ...

# %%
# !python main.py --model_name TGCN --max_epochs 3000 --learning_rate 0.001 --weight_decay 0 --batch_size 32 --hidden_dim 64 --loss mse_with_regularizer --settings supervised --gpus 1
